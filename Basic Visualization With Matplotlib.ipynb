# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tseries.offsets import BDay
from pandas_datareader import data
# %matplotlib inline
import matplotlib.pyplot as plt 
plt.style.use('seaborn-whitegrid') 
import numpy as np

# %%
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
 
# plotting the data
plt.plot(x, y)
 
plt.show()

# %%
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y)

# Adding title to the plot
plt.title("Linear graph", fontsize=25, color="green")

plt.show()

# %%
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y)

# Adding title to the plot
plt.title("Linear graph", fontsize=25, color="green")

# Adding label on the y-axis
plt.ylabel('Y-Axis')

# Adding label on the x-axis
plt.xlabel('X-Axis')

# Setting the limit of y-axis
plt.ylim(0, 80)

# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])

plt.show()

# %%
from matplotlib.figure import Figure

# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# Creating a new figure with width = 7 inches
# and height = 5 inches with face color as
# green, edgecolor as red and the line width
# of the edge as 7
fig = plt.figure(figsize =(7, 5), facecolor='g',
				edgecolor='b', linewidth=7)

# Creating a new axes for the figure
ax = fig.add_axes([1, 1, 1, 1])

# Adding the data to be plotted
ax.plot(x, y)

# Adding title to the plot
plt.title("Linear graph", fontsize=25, color="yellow")

# Adding label on the y-axis
plt.ylabel('Y-Axis')

# Adding label on the x-axis
plt.xlabel('X-Axis')

# Setting the limit of y-axis
plt.ylim(0, 80)

# setting the labels of x-axis
plt.xticks(x, labels=["one", "two", "three", "four"])

# Adding legends
plt.legend(["GFG"])

plt.show()

# %%
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
 
fig = plt.figure(figsize = (5, 4))
 
# Adding the axes to the figure
ax = fig.add_axes([1, 1, 1, 1])
 
# plotting 1st dataset to the figure
ax1 = ax.plot(x, y)
 
# plotting 2nd dataset to the figure
ax2 = ax.plot(y, x)
 
# Setting Title
ax.set_title("Linear Graph")
 
# Setting Label
ax.set_xlabel("X-Axis")
ax.set_ylabel("Y-Axis")
 
# Adding Legend
ax.legend(labels = ('line 1', 'line 2'))
 
plt.show()

# %%
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]


# Creating figure object
plt.figure()

# adding first subplot
plt.subplot(121)
plt.plot(x, y)

# adding second subplot
plt.subplot(122)
plt.plot(y, x)

# %%
import matplotlib.pyplot as plt


# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# Creating the figure and subplots
# according the argument passed
fig, axes = plt.subplots(1, 5)

# plotting the data in the
# 1st subplot
axes[0].plot(x, y)

# plotting the data in the 1st
# subplot only
axes[0].plot(y, x)

# plotting the data in the 2nd
# subplot only
axes[1].plot(x, y)

# %%
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# adding the subplots
axes1 = plt.subplot2grid (
(7, 1), (0, 0), rowspan = 2, colspan = 1)

axes2 = plt.subplot2grid (
(7, 1), (2, 0), rowspan = 2, colspan = 1)

# plotting the data
axes1.plot(x, y)
axes2.plot(y, x)

# %%
# initializing the data
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]

# plotting the data
plt.plot(x, y, color='green', linewidth=3, marker='o',
		markersize=15, linestyle='--')

# Adding title to the plot
plt.title("Line Chart")

# Adding label on the y-axis
plt.ylabel('Y-Axis')

# Adding label on the x-axis
plt.xlabel('X-Axis')

plt.show()

# %%
# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
		'Python':35}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon',
		width = 0.4)

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
values
# Out:
# [20, 15, 30, 35]

# %%
courses
# Out:
# ['C', 'C++', 'Java', 'Python']

# %%
# Out:
#   File "C:\Users\MUZAMM~1\AppData\Local\Temp/ipykernel_2224/3390677928.py", line 1
#     x=[43 23 1 23 4 34134 41 413 4 4 4 43 434 53 63 4 75 86 3 537  734 53 ]
#           ^
# SyntaxError: invalid syntax

# %%
x=[2,3,4,5,5,6]
y=[4,6,7,3,4,5]

# %%
plt.axis
# Out:
# <function matplotlib.pyplot.axis(*args, emit=True, **kwargs)>

# %%
plt.figure
# Out:
# <function matplotlib.pyplot.figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True, FigureClass=<class 'matplotlib.figure.Figure'>, clear=False, **kwargs)>

# %%
plt.axis()
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.figure()

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.plot(x,y,'-k',y,x,'--r')
# Out:
# [<matplotlib.lines.Line2D at 0x1a64294b3a0>,
#  <matplotlib.lines.Line2D at 0x1a64294b4c0>]

# %%
plt.show()

# %%
fig=plt.figure()

# %%
ax=plt.axis()

# %%
#ax.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\MUZAMM~1\AppData\Local\Temp/ipykernel_2224/837966331.py in <module>
# ----> 1 ax.plot(x,y)
#
# AttributeError: 'tuple' object has no attribute 'plot'

# %%
fig = plt.figure() 
ax.plot(x,y);

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
plt.plot(x,y)

# %%
plt.xlim(3,5)
# Out:
# (3.0, 5.0)

# %%
plt.plot(x,y,'-k',y,x,'--r')
plt.title("Sales Data",fontsize=25,color="red")
plt.xlabel("sales data")
plt.ylabel("index_year")
# Out:
# Text(0, 0.5, 'index_year')

# %%
plt.plot(x,y,'-k',y,x,'--r')
plt.title("Sales Data",fontsize=25,color="red")
# Out:
# Text(0.5, 1.0, 'Sales Data')

# %%
plt.scatter(x,y)
plt.title("Sales Data",fontsize=25,color="red")
# Out:
# Text(0.5, 1.0, 'Sales Data')

# %%
ax = plt.axes()
xx=np.linspace(1,100,200)
yy=np.sin(xx)
ax.plot(xx,yy)
ax.set(xlim=(0, 10), ylim=(-2, 2), 
xlabel='x', ylabel='sin(x)', 
title='A Simple Plot');

# %%
plt.figure()
plt.subplot(3,1,1)
plt.plot(xx,yy)
plt.subplot(3,1,3)
plt.plot(yy,xx)
